# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizhfadhullah/Python/blob/main/MYC/CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for MYC proto-oncogene HUMAN**
#
# ---

# %%
# Target search for MYC Proto-oncogene Human
target = new_client.target
target_query = target.search('CHEMBL1250348')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0                                                 []  Homo sapiens
# 1  [{'xref_id': 'CPX-91', 'xref_name': 'MYC-MAX t...  Homo sapiens
# 2                                                 []  Homo sapiens
# 3                                                 []  Homo sapiens
# 4                                                 []  Homo sapiens
# 5                                                 []  Homo sapiens
# 6                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0                         Myc proto-oncogene protein   12.0
# 1                                          c-Myc/Max    8.0
# 2                                        c-Myc/c-Max    8.0
# 3                  MAP2K3/Myc proto-oncogene protein    8.0
# 4                                           WDR5-MYC    7.0
# 5  von Hippel-Lindau disease tumor suppressor/Myc...    1.0
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human MYC* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human MYC*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1250348'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human MYC* that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 931  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 932  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 933  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 934  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 935  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('MYC_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-14-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 931  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 932  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 933  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 934  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 899

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 931  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 932  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 933  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 934  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 935  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL1336889       O=C(O)c1ccc(Nc2ccc([N+](=O)[O-])c3nonc23)cc1
# 1        CHEMBL2312756      O=[N+]([O-])c1ccc(Nc2ccccc2-c2ccccc2)c2nonc12
# 2            CHEMBL165                     Oc1ccc(/C=C/c2cc(O)cc(O)c2)cc1
# 3        CHEMBL1172104              COc1cc(/C=C\c2ccc(OC)c(OC)c2)cc(OC)c1
# 4        CHEMBL3222133        CC(C)c1ccc(/C=C2\SC(=S)N(CN3CCCCC3)C2=O)cc1
# ..                 ...                                                ...
# 931      CHEMBL5069754  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1Cl)c1ncc...
# 932      CHEMBL5080039  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cn1)c1ncc(C...
# 933      CHEMBL5084198  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1F)c1ncc(...
# 934      CHEMBL5090513  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1F)c1ncc(...
# 935      CHEMBL5075294  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1F)c1ncc(...
#
#     standard_value
# 0          33000.0
# 1         146000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('MYC_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('MYC_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL1336889       O=C(O)c1ccc(Nc2ccc([N+](=O)[O-])c3nonc23)cc1
# 1        CHEMBL2312756      O=[N+]([O-])c1ccc(Nc2ccccc2-c2ccccc2)c2nonc12
# 2            CHEMBL165                     Oc1ccc(/C=C/c2cc(O)cc(O)c2)cc1
# 3        CHEMBL1172104              COc1cc(/C=C\c2ccc(OC)c(OC)c2)cc(OC)c1
# 4        CHEMBL3222133        CC(C)c1ccc(/C=C2\SC(=S)N(CN3CCCCC3)C2=O)cc1
# ..                 ...                                                ...
# 894      CHEMBL5069754  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1Cl)c1ncc...
# 895      CHEMBL5080039  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cn1)c1ncc(C...
# 896      CHEMBL5084198  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1F)c1ncc(...
# 897      CHEMBL5090513  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1F)c1ncc(...
# 898      CHEMBL5075294  [2H]C([2H])([2H])c1nnn(C)c1-c1cc2c(cc1F)c1ncc(...
#
#      standard_value     class
# 0           33000.0  inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('MYC_03_bioactivity_data_curated.csv', index=False)

# %%
! zip MYC.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 95%)
#   adding: MYC_01_bioactivity_data_raw.csv (deflated 95%)
#   adding: MYC_02_bioactivity_data_preprocessed.csv (deflated 84%)
#   adding: MYC_03_bioactivity_data_curated.csv (deflated 85%)

# %%
! ls -l
# Out:
# total 1492
# -rw-r--r-- 1 root root 601851 Jan 28 11:14 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  85459 Jan 28 11:16 acetylcholinesterase.zip
# -rw-r--r-- 1 root root 601851 Jan 28 11:15 MYC_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  67631 Jan 28 11:16 MYC_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  74932 Jan 28 11:16 MYC_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  85459 Jan 28 11:21 MYC.zip
# drwxr-xr-x 1 root root   4096 Jan 24 14:22 sample_data

# %% [markdown]
# ---
